# %% [markdown]
# <a href="https://colab.research.google.com/github/artadchy/Study-Material-/blob/main/Homework.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Homework 1

# %%
num1 = 30
num2 = 10

sum = num1 + num2
print(sum)

sub= num1 - num2
print(sub)

mul = num1 * num2
print(mul)

div = num1 // num2
print(div)
# Out:
# 40
# 20
# 300
# 3

# %% [markdown]
# #Homework 2

# %%
id, name, batch, hometown, value =  "1", "Md Artad Chowdhury", ""
